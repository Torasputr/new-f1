# %%
from google.cloud import storage
import os
from dotenv import load_dotenv
import pandas as pd
from io import BytesIO

load_dotenv()
# Out:
# c:\Users\USER\anaconda3\envs\DataEngineering\lib\site-packages\google\auth\__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# c:\Users\USER\anaconda3\envs\DataEngineering\lib\site-packages\google\oauth2\__init__.py:40: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# c:\Users\USER\anaconda3\envs\DataEngineering\lib\site-packages\google\api_core\_python_version_support.py:242: FutureWarning: You are using a non-supported Python version (3.9.25). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# True

# %%
GCS_BUCKET = os.getenv("GCS_BUCKET", "").strip()
GCS_MEDAL_FETCH = os.getenv("GCS_MEDAL_FETCH", "").strip()
GCS_MEDAL_PUSH = os.getenv("GCS_MEDAL_PUSH", "").strip()
SEASON = int(os.getenv("SEASON", ""))
GCS_BLOB_FETCH = f"{GCS_MEDAL_FETCH}/season={SEASON}/driver.parquet"

# %%
print(f"[INFO] Fetching drivers for season {SEASON} from {GCS_BLOB_FETCH}")
client = storage.Client()
bucket = client.bucket(GCS_BUCKET)
blob = bucket.blob(GCS_BLOB_FETCH)

df = pd.read_parquet(BytesIO(blob.download_as_bytes()))
# Out:
# [INFO] Fetching drivers for season 2026 from silver/season=2026/driver.parquet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   driver_number   22 non-null     int64
#  1   broadcast_name  22 non-null     object
#  2   full_name       22 non-null     object
#  3   name_acronym    22 non-null     object
#  4   team_name       22 non-null     object
#  5   team_colour     22 non-null     object
#  6   first_name      22 non-null     object
#  7   last_name       22 non-null     object
#  8   headshot_url    22 non-null     object
#  9   country         22 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 1.8+ KB

# %%
df.head()
# Out:
#    driver_number broadcast_name          full_name name_acronym  \
# 0              1       L NORRIS       Lando NORRIS          NOR
# 1              3   M VERSTAPPEN     Max VERSTAPPEN          VER
# 2              5    G BORTOLETO  Gabriel BORTOLETO          BOR
# 3              6       I HADJAR       Isack HADJAR          HAD
# 4             10        P GASLY       Pierre GASLY          GAS
#
#          team_name team_colour first_name   last_name  \
# 0          McLaren      F47600      Lando      Norris
# 1  Red Bull Racing      4781D7        Max  Verstappen
# 2             Audi      F50537    Gabriel   Bortoleto
# 3  Red Bull Racing      4781D7      Isack      Hadjar
# 4           Alpine      00A1E8     Pierre       Gasly
#
#                                         headshot_url         country
# 0  https://media.formula1.com/d_driver_fallback_i...  United Kingdom
# 1  https://media.formula1.com/d_driver_fallback_i...     Netherlands
# 2  https://media.formula1.com/d_driver_fallback_i...          Brazil
# 3  https://media.formula1.com/d_driver_fallback_i...          France
# 4  https://media.formula1.com/d_driver_fallback_i...          France
